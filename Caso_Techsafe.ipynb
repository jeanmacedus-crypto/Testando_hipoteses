# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanmacedus-crypto/Testando_hipoteses/blob/main/Caso_Techsafe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Techsafe é uma empresa de tecnologia que lançou recentemente um novo software de compressão de dados, alegando que ele é capaz de reduzir significativamente o tamanho dos arquivos em comparação com a versão anterior. A equipe de desenvolvimento está interessada em verificar se, de fato, o novo software alcança uma média de compressão superior a 20%

# %%
import pandas as pd

# Conjunto de dados Techsafe
df_techsafe = pd.DataFrame({'porcentagem_compressao': [21.99342831, 20.7234714 , 22.29537708, 24.04605971, 20.53169325, 20.53172609, 24.15842563, 22.53486946, 20.06105123, 22.08512009, 20.07316461, 20.06854049, 21.48392454, 17.17343951, 17.55016433, 19.87542494, 18.97433776, 21.62849467, 19.18395185, 18.1753926, 23.93129754, 20.5484474 , 21.13505641, 18.15050363, 19.91123455]})

# %%
df_techsafe
# Out:
#     porcentagem_compressao
# 0                21.993428
# 1                20.723471
# 2                22.295377
# 3                24.046060
# 4                20.531693
# 5                20.531726
# 6                24.158426
# 7                22.534869
# 8                20.061051
# 9                22.085120
# 10               20.073165
# 11               20.068540
# 12               21.483925
# 13               17.173440
# 14               17.550164
# 15               19.875425
# 16               18.974338
# 17               21.628495
# 18               19.183952
# 19               18.175393
# 20               23.931298
# 21               20.548447
# 22               21.135056
# 23               18.150504
# 24               19.911235

# %% [markdown]
# Formule uma hipótese para o caso da Techsafe.
#
# H₀: μ = 20
#
# H₁: μ > 20

# %%
# Calculando a média amostral dos dados.
media_amostral = df_techsafe['porcentagem_compressao'].mean()
media_amostral
# Out:
# np.float64(20.6729838832)

# %%
# Estabeleça um nível de confiança para o problema e calcule o nível de significância.
nivel_confianca = 0.95
nivel_significancia = 1 - nivel_confianca

# %%
# Utilize o Teste t para calcular o valor da estatística t e o p-valor para o problema da Techsasfe, mostre os dados.
from scipy.stats import ttest_1samp

# Realiza o teste t unilateral para uma amostra
stats, p_valor = ttest_1samp(df_techsafe, popmean=20, alternative='greater')

print(f'Valor da estatística t: {stats}')
print(f'Valor do p-valor: {p_valor}')
# Out:
# Valor da estatística t: [1.75887757]
# Valor do p-valor: [0.045672]

# %%
# Pelos resultados anteriores, a hipótese nula formulada é rejeitada ou não rejeitada? Explique o que justifica sua decisão.

#interpretando o test T
if p_valor < nivel_significancia:
    conclusao = "Rejeitar a hipótese nula"
else:
    conclusao = "Não rejeita a hipótese nula"

conclusao
# Out:
# 'Rejeitar a hipótese nula'
